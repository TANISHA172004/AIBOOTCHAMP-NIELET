# %%
#Multiply
a=int(input("Enter a Number"))
b=int(input("Enter a Number"))
c=a*b
print(c)
# Out:
# Enter a Number36
# Enter a Number45
# 1620

# %%
#Multiply
a=int(input("Enter a Number"))
b=int(input("Enter a Number"))
c=a*b
print(c)
# Out:
# Enter a Number12
# Enter a Number26
# 312
